# %% [markdown]
# # 03 - Exploratory Data Analysis (EDA)
#
# ## Objective
# Explore the cleaned price dataset to understand trends, volatility, and relationships between tickers.
# Generate insights and plots that will later support dashboard visuals and project hypotheses.
#
# ## Inputs
# - Cleaned dataset: `data/processed/<version>/clean_prices_<version>_latest.csv`
#
# ## Outputs
# - EDA plots displayed in-notebook
# - Optional saved figures to: `outputs/<version>/figures/`
# - Summary stats (returns, volatility, drawdown)
#
# ## CRISP-DM Stage
# Data Understanding

# %%
# Make the project root importable (so `import src...` works in notebooks)
import sys
from pathlib import Path

PROJECT_ROOT = Path("..").resolve()  # notebooks live in jupyter_notebooks/
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added to sys.path:", PROJECT_ROOT)
# Out:
# Project root added to sys.path: C:\Users\Louis\Documents\vscode-projects\stockmetrics

# %%
from pathlib import Path

import pandas as pd
import matplotlib.pyplot as plt

from src.config import DEFAULT_VERSION, get_paths

# %%
VERSION = DEFAULT_VERSION
paths = get_paths(VERSION)

PROCESSED_DIR = paths.processed_dir
OUTPUT_FIG_DIR = paths.outputs_dir / "figures"
OUTPUT_FIG_DIR.mkdir(parents=True, exist_ok=True)

data_path = PROCESSED_DIR / f"clean_prices_{VERSION}_latest.csv"
print("Loading:", data_path)

df = pd.read_csv(data_path, parse_dates=["Date"])

print("Shape:", df.shape)
print("Tickers:", sorted(df["Ticker"].unique().tolist()))
print("Date range:", df["Date"].min().date(), "to", df["Date"].max().date())
df.head()
# Out:
# Loading: C:\Users\Louis\Documents\vscode-projects\stockmetrics\data\processed\v2\clean_prices_v2_latest.csv
# Shape: (31307, 8)
# Tickers: ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA', 'VUSA.L', 'VWRL.L']
# Date range: 2012-05-22 to 2026-03-18
#         Date       Open       High        Low      Close  Adj_Close  Volume  \
# 0 2012-05-22  31.299999  31.299999  31.299999  31.299999  24.923445       0
# 1 2012-05-23  31.299999  31.299999  31.299999  31.184999  24.831869     159
# 2 2012-05-24  31.540001  31.639999  31.540001  31.690001  25.233997    2614
# 3 2012-05-25  31.670000  31.670000  31.670000  31.705000  25.245939    2014
# 4 2012-05-29  31.850000  32.160000  31.850000  32.150002  25.600286    2221
#
#    Ticker
# 0  VWRL.L
# 1  VWRL.L
# 2  VWRL.L
# 3  VWRL.L
# 4  VWRL.L

# %%
# Basic sanity checks
expected_cols = ["Date", "Open", "High", "Low", "Close", "Adj_Close", "Volume", "Ticker"]
missing_cols = [c for c in expected_cols if c not in df.columns]
if missing_cols:
    raise KeyError(f"Missing expected columns: {missing_cols}")

df = df.sort_values(["Ticker", "Date"]).reset_index(drop=True)

# Ensure numeric types
for col in ["Open", "High", "Low", "Close", "Adj_Close", "Volume"]:
    df[col] = pd.to_numeric(df[col], errors="coerce")

print(df.dtypes)
df.isna().mean().sort_values(ascending=False).head(10) * 100
# Out:
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj_Close           float64
# Volume                int64
# Ticker               object
# dtype: object
# Date         0.0
# Open         0.0
# High         0.0
# Low          0.0
# Close        0.0
# Adj_Close    0.0
# Volume       0.0
# Ticker       0.0
# dtype: float64

# %%
# Wide format for time series comparisons
prices = df.pivot(index="Date", columns="Ticker", values="Adj_Close").sort_index()

print("Wide prices shape:", prices.shape)
prices.tail()
# Out:
# Wide prices shape: (3555, 9)
# Ticker            AAPL        AMZN       GOOGL        META        MSFT  \
# Date
# 2026-03-12  255.759995  209.529999  303.549988  637.634094  401.859985
# 2026-03-13  250.119995  207.669998  302.279999  613.184998  395.549988
# 2026-03-16  252.820007  211.740005  305.559998  627.450012  399.950012
# 2026-03-17  254.229996  215.199997  310.920013  622.659973  399.410004
# 2026-03-18  249.940002  209.869995  307.690002  615.679993  391.790009
#
# Ticker            NVDA        TSLA     VUSA.L      VWRL.L
# Date
# 2026-03-12  183.139999  395.010010  95.324997  123.800003
# 2026-03-13  180.250000  391.200012  95.447502  123.769997
# 2026-03-16  183.220001  395.559998  95.504997  124.269997
# 2026-03-17  181.929993  399.269989  95.642502  124.650002
# 2026-03-18  180.399994  392.779999  95.074997  123.839996

# %%
plt.figure()
prices.plot()
plt.title("Adjusted Close Price Over Time")
plt.xlabel("Date")
plt.ylabel("Adj Close")
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_adj_close_timeseries.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()
# Out:
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_adj_close_timeseries.png

# %%
# Daily returns (percent)
returns = prices.pct_change().dropna()

plt.figure()
returns.plot()
plt.title("Daily Returns Over Time")
plt.xlabel("Date")
plt.ylabel("Daily Return")
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_daily_returns_timeseries.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()
# Out:
# C:\Users\Louis\AppData\Local\Temp\ipykernel_16280\162638347.py:2: FutureWarning: The default fill_method='pad' in DataFrame.pct_change is deprecated and will be removed in a future version. Call ffill before calling pct_change to retain current behavior and silence this warning.
#   returns = prices.pct_change().dropna()
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_daily_returns_timeseries.png

# %%
plt.figure()
returns.plot(kind="hist", bins=60, alpha=0.6)
plt.title("Distribution of Daily Returns")
plt.xlabel("Daily Return")
plt.ylabel("Frequency")
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_daily_returns_hist.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()
# Out:
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_daily_returns_hist.png

# %%
plt.figure()
returns.boxplot()
plt.title("Daily Returns Boxplot (Volatility Comparison)")
plt.ylabel("Daily Return")
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_daily_returns_boxplot.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()
# Out:
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_daily_returns_boxplot.png

# %%
# Rolling volatility (30-day standard deviation of returns)
rolling_vol = returns.rolling(30).std()

plt.figure()
rolling_vol.plot()
plt.title("30-Day Rolling Volatility")
plt.xlabel("Date")
plt.ylabel("Rolling Std (Volatility)")
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_rolling_volatility_30d.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()
# Out:
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_rolling_volatility_30d.png

# %%
corr = returns.corr()

plt.figure()
plt.imshow(corr, aspect="auto")
plt.title("Correlation of Daily Returns")
plt.xticks(range(len(corr.columns)), corr.columns, rotation=45)
plt.yticks(range(len(corr.index)), corr.index)
plt.colorbar()
plt.tight_layout()

out_path = OUTPUT_FIG_DIR / "eda_returns_correlation_heatmap.png"
plt.savefig(out_path, dpi=150)
print("Saved:", out_path)
plt.show()

corr
# Out:
# Saved: C:\Users\Louis\Documents\vscode-projects\stockmetrics\outputs\v2\figures\eda_returns_correlation_heatmap.png
# Ticker      AAPL      AMZN     GOOGL      META      MSFT      NVDA      TSLA  \
# Ticker
# AAPL    1.000000  0.488523  0.536339  0.434061  0.582326  0.487361  0.379448
# AMZN    0.488523  1.000000  0.606280  0.518238  0.588529  0.483712  0.376881
# GOOGL   0.536339  0.606280  1.000000  0.528002  0.629827  0.502579  0.363617
# META    0.434061  0.518238  0.528002  1.000000  0.476638  0.427858  0.299058
# MSFT    0.582326  0.588529  0.629827  0.476638  1.000000  0.571935  0.367962
# NVDA    0.487361  0.483712  0.502579  0.427858  0.571935  1.000000  0.383101
# TSLA    0.379448  0.376881  0.363617  0.299058  0.367962  0.383101  1.000000
# VUSA.L  0.312134  0.294689  0.333856  0.252925  0.357363  0.302971  0.257316
# VWRL.L  0.333949  0.314919  0.357273  0.268852  0.382479  0.323006  0.273145
#
# Ticker    VUSA.L    VWRL.L
# Ticker
# AAPL    0.312134  0.333949
# AMZN    0.294689  0.314919
# GOOGL   0.333856  0.357273
# META    0.252925  0.268852
# MSFT    0.357363  0.382479
# NVDA    0.302971  0.323006
# TSLA    0.257316  0.273145
# VUSA.L  1.000000  0.962015
# VWRL.L  0.962015  1.000000

# %%
def max_drawdown(series: pd.Series) -> float:
    """
    Max drawdown from a price series.
    Returns a negative number (e.g., -0.55 means -55%).
    """
    running_max = series.cummax()
    drawdown = series / running_max - 1.0
    return drawdown.min()

drawdowns = {t: max_drawdown(prices[t].dropna()) for t in prices.columns}
dd_df = pd.DataFrame.from_dict(drawdowns, orient="index", columns=["Max_Drawdown"])
dd_df.sort_values("Max_Drawdown")
# Out:
#         Max_Drawdown
# META       -0.767361
# TSLA       -0.736322
# NVDA       -0.663351
# AMZN       -0.561453
# GOOGL      -0.443201
# AAPL       -0.437972
# MSFT       -0.371485
# VUSA.L     -0.254738
# VWRL.L     -0.249848

# %%
summary = pd.DataFrame({
    "Mean_Daily_Return": returns.mean(),
    "Std_Daily_Return": returns.std(),
    "Annualised_Return_Approx": returns.mean() * 252,
    "Annualised_Volatility_Approx": returns.std() * (252 ** 0.5),
}).sort_values("Annualised_Volatility_Approx", ascending=False)

summary
# Out:
#         Mean_Daily_Return  Std_Daily_Return  Annualised_Return_Approx  \
# Ticker
# TSLA             0.002110          0.035658                  0.531802
# NVDA             0.002214          0.028100                  0.558042
# META             0.001145          0.024602                  0.288654
# AMZN             0.001036          0.020048                  0.261156
# AAPL             0.000917          0.017609                  0.231047
# GOOGL            0.000998          0.017135                  0.251563
# MSFT             0.000924          0.016281                  0.232808
# VUSA.L           0.000601          0.009523                  0.151522
# VWRL.L           0.000490          0.008833                  0.123554
#
#         Annualised_Volatility_Approx
# Ticker
# TSLA                        0.566054
# NVDA                        0.446075
# META                        0.390549
# AMZN                        0.318249
# AAPL                        0.279528
# GOOGL                       0.272002
# MSFT                        0.258460
# VUSA.L                      0.151176
# VWRL.L                      0.140224
