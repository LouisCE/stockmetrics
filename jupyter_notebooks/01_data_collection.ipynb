# %% [markdown]
# # 01 - Data Collection
#
# ## Objective
# Collect historical OHLCV stock/ETF price data from the Yahoo Finance endpoint via `yfinance`, and save versioned raw snapshots for reproducible analysis.
#
# ## Inputs
# - Ticker symbols list
# - Date range
# - Output version label (e.g., v1)
#
# ## Outputs
# - One raw CSV per ticker saved to `data/raw/<version>/`
# - Combined preview DataFrame (head) to confirm successful collection
#
# ## CRISP-DM Stage
# Data Collection

# %%
from pathlib import Path
from datetime import datetime, timezone

import pandas as pd
import yfinance as yf

# %%
# Settings for this run
VERSION = "v1"

# Keeping this small until everything is stable
TICKERS = ["SPY", "TSLA"]

# Date range (might expand later)
START_DATE = "2010-01-01"
END_DATE = datetime.now(timezone.utc).strftime("%Y-%m-%d")

# Paths (notebook lives in jupyter_notebooks/)
PROJECT_ROOT = Path("..").resolve()
RAW_DATA_DIR = PROJECT_ROOT / "data" / "raw" / VERSION
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)

print("Project root:", PROJECT_ROOT)
print("Saving raw data to:", RAW_DATA_DIR)
print("Date range:", START_DATE, "to", END_DATE)
print("Tickers:", ", ".join(TICKERS))
# Out:
# Project root: C:\Users\Louis\Documents\vscode-projects\stockmetrics
# Saving raw data to: C:\Users\Louis\Documents\vscode-projects\stockmetrics\data\raw\v1
# Date range: 2010-01-01 to 2026-02-14
# Tickers: SPY, TSLA

# %%
def download_stock_data(ticker: str, start: str, end: str) -> pd.DataFrame:
    """
    Download historical OHLCV data from Yahoo Finance via yfinance.
    Returns a tidy DataFrame with a Date column and Ticker column.
    """
    df = yf.download(
        ticker,
        start=start,
        end=end,
        auto_adjust=False,
        progress=False
    )

    if df is None or df.empty:
        raise ValueError(f"No data returned for ticker: {ticker}")

    # Reset index so Date becomes a column
    df = df.reset_index()

    # Add ticker column
    df["Ticker"] = ticker

    return df

# %%
all_data = []
failed = []
timestamp = datetime.now(timezone.utc).strftime("%Y%m%d_%H%M%S")

for ticker in TICKERS:
    try:
        print(f"Downloading {ticker}...")
        df = download_stock_data(ticker, START_DATE, END_DATE)

        file_path = RAW_DATA_DIR / f"{ticker}_raw_{VERSION}_{timestamp}.csv"
        df.to_csv(file_path, index=False)

        print(f"Saved: {file_path.name} | rows: {len(df):,}")
        all_data.append(df)

    except Exception as e:
        print(f"ERROR for {ticker}: {e}")
        failed.append(ticker)

if not all_data:
    raise RuntimeError(
        "No data was downloaded for any ticker. "
        "This is usually a Yahoo/yfinance connectivity or version issue."
    )

print("Failed tickers:", failed)

# Show a quick preview per ticker
for df in all_data:
    ticker = df["Ticker"].iloc[0]
    print(f"\nPreview for {ticker}:")
    display(df.head(5))
# Out:
# Downloading SPY...
# Saved: SPY_raw_v1_20260214_194011.csv | rows: 4,054
# Downloading TSLA...
# Saved: TSLA_raw_v1_20260214_194011.csv | rows: 3,932
# Failed tickers: []
#
# Preview for SPY:
# Price        Date  Adj Close       Close        High         Low        Open  \
# Ticker                   SPY         SPY         SPY         SPY         SPY
# 0      2010-01-04  85.027946  113.330002  113.389999  111.510002  112.370003
# 1      2010-01-05  85.253014  113.629997  113.680000  112.849998  113.260002
# 2      2010-01-06  85.313042  113.709999  113.989998  113.430000  113.519997
# 3      2010-01-07  85.673180  114.190002  114.330002  113.180000  113.500000
# 4      2010-01-08  85.958282  114.570000  114.620003  113.660004  113.889999
#
# Price      Volume Ticker
# Ticker        SPY
# 0       118944600    SPY
# 1       111579900    SPY
# 2       116074400    SPY
# 3       131091100    SPY
# 4       126402800    SPY
# Preview for TSLA:
# Price        Date Adj Close     Close      High       Low      Open  \
# Ticker                 TSLA      TSLA      TSLA      TSLA      TSLA
# 0      2010-06-29  1.592667  1.592667  1.666667  1.169333  1.266667
# 1      2010-06-30  1.588667  1.588667  2.028000  1.553333  1.719333
# 2      2010-07-01  1.464000  1.464000  1.728000  1.351333  1.666667
# 3      2010-07-02  1.280000  1.280000  1.540000  1.247333  1.533333
# 4      2010-07-06  1.074000  1.074000  1.333333  1.055333  1.333333
#
# Price      Volume Ticker
# Ticker       TSLA
# 0       281494500   TSLA
# 1       257806500   TSLA
# 2       123282000   TSLA
# 3        77097000   TSLA
# 4       103003500   TSLA
