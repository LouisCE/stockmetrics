# %% [markdown]
# # 01 - Data Collection
#
# ## Objective
# Collect historical OHLCV stock/ETF price data from the Yahoo Finance endpoint via `yfinance`, and save versioned raw snapshots for reproducible analysis.
#
# ## Inputs
# - Ticker symbols list
# - Date range
# - Output version label (e.g., v2)
#
# ## Outputs
# - One raw CSV per ticker saved to `data/raw/<version>/`
# - Combined preview DataFrame (head) to confirm successful collection
#
# ## CRISP-DM Stage
# Data Understanding
#
# ## External Endpoint and Reproducibility Notice
#
# This notebook collects data from Yahoo Finance using `yfinance`. Because Yahoo Finance is a live third-party endpoint, temporary upstream issues such as rate limiting, empty responses, API changes, or timezone parsing failures may occasionally affect live collection.
#
# To protect reproducibility, successfully collected raw snapshots are stored in `data/raw/<version>/`. The downstream notebooks use these saved raw snapshots so the rest of the CRISP-DM pipeline can still be rerun consistently even if the live endpoint is temporarily unavailable during assessment.

# %%
# Make the project root importable (so `import src...` works in notebooks)
import sys
from pathlib import Path

# notebooks live in jupyter_notebooks/
PROJECT_ROOT = Path("..").resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added to sys.path:", PROJECT_ROOT)

from src.config import (
    DEFAULT_END_DATE,
    DEFAULT_START_DATE,
    DEFAULT_TICKERS,
    DEFAULT_VERSION,
    get_paths,
)
from src.data_collection import download_many
# Out:
# Project root added to sys.path: C:\Users\Louis\Documents\vscode-projects\stockmetrics

# %%
# Settings for this run (now controlled centrally)
VERSION = DEFAULT_VERSION
TICKERS = DEFAULT_TICKERS
START_DATE = DEFAULT_START_DATE
END_DATE = DEFAULT_END_DATE

# Paths
paths = get_paths(VERSION)
RAW_DATA_DIR = paths.raw_dir
RAW_DATA_DIR.mkdir(parents=True, exist_ok=True)

print("Saving raw data to:", RAW_DATA_DIR)
print("Date range:", START_DATE, "to", END_DATE)
print("Tickers:", ", ".join(TICKERS))
# Out:
# Saving raw data to: C:\Users\Louis\Documents\vscode-projects\stockmetrics\data\raw\v2
# Date range: 2012-05-22 to 2026-03-19
# Tickers: VWRL.L, VUSA.L, AAPL, AMZN, GOOGL, META, MSFT, NVDA, TSLA

# %%
try:
    dfs, failed, saved_paths = download_many(
        tickers=TICKERS,
        start=START_DATE,
        end=END_DATE,
        out_dir=RAW_DATA_DIR,
        version=VERSION,
    )

except Exception as err:
    dfs = []
    failed = [f"Live endpoint unavailable: {err}"]
    saved_paths = []

    print("Live Yahoo Finance collection is currently unavailable.")
    print("This can happen due to temporary endpoint instability,")
    print("rate limiting, or upstream yfinance/Yahoo Finance changes.")
    print()
    print("The project remains reproducible because previously")
    print("collected raw snapshots are stored in:")
    print(RAW_DATA_DIR)

print("Failed tickers:", failed)

if dfs:
    for df in dfs:
        ticker = df["Ticker"].iloc[0]
        print(f"\nPreview for {ticker}:")
        display(df.head(5))

    print("\nSaved files:")
    for p in saved_paths:
        print("-", p.name)

else:
    existing_snapshots = sorted(RAW_DATA_DIR.glob(f"*_raw_{VERSION}_*.csv"))

    print("\nNo new live data files were saved during this validation run.")
    print("Existing saved raw snapshots remain available for reproducibility:")

    for p in existing_snapshots:
        print("-", p.name)
# Out:
# Failed tickers: []
#
# Preview for VWRL.L:
# Price        Date  Adj Close      Close       High        Low       Open  \
# Ticker                VWRL.L     VWRL.L     VWRL.L     VWRL.L     VWRL.L
# 0      2012-05-22  24.923445  31.299999  31.299999  31.299999  31.299999
# 1      2012-05-23  24.831869  31.184999  31.299999  31.299999  31.299999
# 2      2012-05-24  25.233997  31.690001  31.639999  31.540001  31.540001
# 3      2012-05-25  25.245939  31.705000  31.670000  31.670000  31.670000
# 4      2012-05-29  25.600286  32.150002  32.160000  31.850000  31.850000
#
# Price  Volume  Ticker
# Ticker VWRL.L
# 0           0  VWRL.L
# 1         159  VWRL.L
# 2        2614  VWRL.L
# 3        2014  VWRL.L
# 4        2221  VWRL.L
# Preview for VUSA.L:
# Price        Date  Adj Close      Close       High     Low       Open Volume  \
# Ticker                VUSA.L     VUSA.L     VUSA.L  VUSA.L     VUSA.L VUSA.L
# 0      2012-05-22  13.191869  15.772000  15.772000  15.772  15.772000      0
# ...

# %% [markdown]
# ## Conclusion and Next Steps
#
# The data collection stage successfully collected or confirmed the availability of versioned raw Yahoo Finance snapshots for the selected StockMetrics tickers.
#
# The raw data is stored under `data/raw/v2/`, supporting reproducibility and demonstrating endpoint-based data collection for the CRISP-DM Data Collection stage.
#
# The next notebook loads these raw snapshots, cleans the data, standardises the schema, and saves a tidy processed dataset for analysis and modelling.
