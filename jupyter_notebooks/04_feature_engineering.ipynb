# %% [markdown]
# # 04 - Feature Engineering
#
# ## Objective
# Transform the cleaned price dataset into model-ready features (returns, volatility,
# momentum, drawdowns) suitable for time-series forecasting tasks.
#
# ## Inputs
# - Cleaned dataset: `data/processed/<version>/clean_prices_<version>_latest.csv`
#
# ## Outputs
# - Feature dataset saved to: `data/processed/<version>/features_<version>_latest.csv`
# - Timestamped audit copy saved to: `data/processed/<version>/features_<version>_<timestamp>.csv`
#
# ## CRISP-DM Stage
# Data Preparation

# %%
# Make the project root importable (so `import src...` works in notebooks)
import sys
from pathlib import Path

# notebooks live in jupyter_notebooks/
PROJECT_ROOT = Path("..").resolve()

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project root added to sys.path:", PROJECT_ROOT)

from src.config import DEFAULT_VERSION, get_paths
from src.data_processing import load_clean_prices_latest
from src.features import build_features, save_features
# Out:
# Project root added to sys.path: C:\Users\Louis\Documents\vscode-projects\stockmetrics

# %%
VERSION = DEFAULT_VERSION
paths = get_paths(VERSION)

df = load_clean_prices_latest(paths.processed_dir, VERSION)

print("Shape:", df.shape)
print("Tickers:", sorted(df["Ticker"].unique().tolist()))
print(
    "Date range:",
    df["Date"].min().date(),
    "to",
    df["Date"].max().date(),
)
df.head()
# Out:
# Shape: (31307, 8)
# Tickers: ['AAPL', 'AMZN', 'GOOGL', 'META', 'MSFT', 'NVDA', 'TSLA', 'VUSA.L', 'VWRL.L']
# Date range: 2012-05-22 to 2026-03-18
#         Date       Open       High        Low      Close  Adj_Close  Volume  \
# 0 2012-05-22  31.299999  31.299999  31.299999  31.299999  24.923445       0
# 1 2012-05-23  31.299999  31.299999  31.299999  31.184999  24.831869     159
# 2 2012-05-24  31.540001  31.639999  31.540001  31.690001  25.233997    2614
# 3 2012-05-25  31.670000  31.670000  31.670000  31.705000  25.245939    2014
# 4 2012-05-29  31.850000  32.160000  31.850000  32.150002  25.600286    2221
#
#    Ticker
# 0  VWRL.L
# 1  VWRL.L
# 2  VWRL.L
# 3  VWRL.L
# 4  VWRL.L

# %%
feat_df = build_features(df)

print("Feature shape:", feat_df.shape)
display(feat_df.groupby("Ticker").head(2))

archived_path, latest_path = save_features(
    feat_df=feat_df,
    processed_dir=paths.processed_dir,
    version=VERSION,
)

print("Saved:")
print("-", archived_path)
print("-", latest_path)
# Out:
# Feature shape: (30488, 21)
#             Date       Open       High        Low      Close  Adj_Close  \
# 90    2012-10-01  34.349998  34.349998  34.349998  34.349998  27.352087
# 91    2012-10-02  34.310001  34.470001  34.195999  34.119999  27.168957
# 3581  2012-10-01  17.020000  17.129999  17.010000  17.110001  14.310986
# 3582  2012-10-02  17.010000  17.080000  16.990000  16.990000  14.210617
# 7072  2012-09-28  24.241072  24.325357  23.812500  23.825001  20.074144
# 7073  2012-10-01  23.969999  24.169643  23.446428  23.549643  19.842133
# 10547 2012-09-28  12.807000  12.850000  12.660000  12.716000  12.716000
# 10548 2012-10-01  12.770000  12.808000  12.524500  12.600500  12.600500
# 14022 2012-09-28  18.872623  19.001501  18.797548  18.881380  18.726606
# 14023 2012-10-01  18.995245  19.144144  18.924173  19.063564  18.907297
# 17497 2012-09-28  20.570000  21.950001  20.500000  21.660000  21.491346
# 17498 2012-10-01  22.080000  22.590000  21.730000  21.990000  21.818777
# ...

# %% [markdown]
# ## Feature Engineering Rationale
#
# The goal of feature engineering was to create simple, interpretable time-series indicators that may help explain short-term price movements.
#
# ### Features Created
#
# #### Returns
# - `return_1d`
# - `log_return_1d`
#
# #### Volatility
# - `vol_30d`
# - `vol_90d`
#
# #### Momentum
# - `mom_30d`
# - `mom_90d`
#
# #### Mean Reversion Signals
# - `zscore_30d`
# - `mean_reversion_5d`
#
# #### Risk / Drawdown
# - `drawdown`
#
# #### Lag Features
# - `lag_return_1`
# - `lag_return_5`
# - `lag_return_21`
#
# #### Target
# - `target_next_day_return` (forward-shifted next-day return)
#
# ### Why This Matters
# These features are commonly used in financial time-series modelling and provide a balance between simplicity, interpretability, and practical usefulness.
#
# They were chosen to align with a beginner-focused educational project while still demonstrating realistic machine learning workflow practices.
#
# The added mean reversion signals were included as lightweight, interpretable features to test whether short-term relative price movement contained any additional predictive signal without materially increasing model complexity or runtime.

# %% [markdown]
# ## Conclusion and Next Steps
#
# The cleaned price dataset was transformed into model-ready features including returns, volatility, momentum, mean reversion, drawdown, lag features, and the next-day return target.
#
# The feature dataset is stored under `data/processed/v2/`, with both a timestamped audit copy and a stable `latest` file.
#
# The next notebook uses these engineered features to train and tune the machine learning pipeline.
